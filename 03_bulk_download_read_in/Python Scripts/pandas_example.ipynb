# %% [markdown]
# ### Loading a table by name

# %%
import csv
import pandas as pd

def load_patentsview_table(table_name: str, **kwargs):
    if table_name.startswith('g_'):
        database_url = 'https://s3.amazonaws.com/data.patentsview.org/download'
    elif table_name.startswith('pg_'):
        database_url = 'https://s3.amazonaws.com/data.patentsview.org/pregrant_publications'
    else:
        raise ValueError("Invalid table name:", table_name)
    
    table_url = f"{database_url}/{table_name}.tsv.zip"

    return pd.read_csv(table_url, delimiter="\t", dtype='str[pyarrow]', quoting=csv.QUOTE_NONNUMERIC, **kwargs)

# %% [markdown]
# Load a granted patent data table:

# %%
load_patentsview_table('g_applicant_not_disambiguated', nrows=5)
# Out:
#   patent_id applicant_sequence raw_applicant_name_first  \
# 0   9069405                  3                    David
# 1   9117193                  6                 James W.
# 2   9764256                  2           Terence Arthur
# 3  10947428                  1                     <NA>
# 4  11212562                  1                     <NA>
#
#   raw_applicant_name_last raw_applicant_organization applicant_type  \
# 0                  Bordui                       <NA>      applicant
# 1                  Seaman                       <NA>      applicant
# 2                  Devlin                       <NA>      applicant
# 3                    <NA>  PPG Industries Ohio, Inc.      applicant
# 4                    <NA>  Amazon Technologies, Inc.      applicant
#
#   applicant_designation applicant_authority             rawlocation_id
# 0               us-only                <NA>  emcq5f1g8kprye06olw1zqdv8
# 1               us-only                <NA>  fa4w8lgydmaocda6g3a1h65lg
# 2               us-only                <NA>  4pwy4ca2zmjod52ex94xh9sxy
# 3               us-only  obligated-assignee  tkwrlo9614r87fa2f18d9gx8s
# 4               us-only            assignee  csjl4jp4tpws94s01mlyq6h1i

# %% [markdown]
# Load a pre-grant publication data table:

# %%
load_patentsview_table('pg_applicant_not_disambiguated', nrows=5)
# Out:
#       pgpub_id applicant_sequence raw_applicant_name_first  \
# 0  20210012690                  1                    David
# 1  20200326458                  1                     <NA>
# 2  20200075033                  1                     <NA>
# 3  20200075034                  1                     <NA>
# 4  20200075035                  1                   Thomas
#
#   raw_applicant_name_last                         raw_applicant_organization  \
# 0                 General                                               <NA>
# 1                    <NA>                   3M INNOVATIVE PROPERTIES COMPANY
# 2                    <NA>                                   Babblelabs, Inc.
# 3                    <NA>  Yissum Research Development Company of The Heb...
# 4              Garth, III                                               <NA>
#
#   applicant_type applicant_designation applicant_authority  \
# 0      applicant               us-only                <NA>
# 1      applicant               us-only            assignee
# 2      applicant               us-only            assignee
# 3      applicant               us-only            assignee
# 4      applicant               us-only                <NA>
#
#                          rawlocation_id
# 0  a7f527d6-3b8a-11ee-ae79-0a1e30f810d7
# 1  a5ed2c55-3b8a-11ee-ae79-0a1e30f810d7
# 2  0000c51a-0d76-11eb-a344-121df0c29c1e
# 3  0000c676-0d76-11eb-a344-121df0c29c1e
# 4  0000c7a1-0d76-11eb-a344-121df0c29c1e

# %% [markdown]
# **Dictionary with all table names:**

# %%
import yaml
from pprint import pprint

with open("sources.yml") as file:
    sources = yaml.safe_load(file)

pprint(sources, compact=True, width=120)
# Out:
# {'granted': {'database': 'https://s3.amazonaws.com/data.patentsview.org/download',
#              'description': 'https://patentsview.org/download/data-download-dictionary',
#              'loader': '{database}/{table_name}.tsv.zip',
#              'tables': ['g_applicant_not_disambiguated', 'g_application', 'g_assignee_disambiguated',
#                         'g_assignee_not_disambiguated', 'g_attorney_disambiguated', 'g_attorney_not_disambiguated',
#                         'g_botanic', 'g_cpc_at_issue', 'g_cpc_current', 'g_cpc_title', 'g_examiner_not_disambiguated',
#                         'g_figures', 'g_foreign_citation', 'g_foreign_priority', 'g_gov_interest',
#                         'g_gov_interest_contracts', 'g_gov_interest_org', 'g_inventor_disambiguated',
#                         'g_inventor_not_disambiguated', 'g_ipc_at_issue', 'g_location_disambiguated',
#                         'g_location_not_disambiguated', 'g_other_reference', 'g_patent', 'g_patent_abstract',
#                         'g_pct_data', 'g_persistent_assignee', 'g_persistent_inventor', 'g_rel_app_text',
#                         'g_us_application_citation', 'g_us_patent_citation', 'g_us_rel_doc', 'g_us_term_of_grant',
#                         'g_uspc_at_issue', 'g_wipo_technology']},
#  'pre-grant': {'database': 'https://s3.amazonaws.com/data.patentsview.org/pregrant_publications',
#                'description': 'https://patentsview.org/download/pg-data-download-dictionary',
#                'loader': '{database}/{table_name}.tsv.zip',
#                'tables': ['pg_applicant_not_disambiguated', 'pg_assignee_disambiguated',
#                           'pg_assignee_not_disambiguated', 'pg_cpc_at_issue', 'pg_cpc_current', 'pg_cpc_title',
#                           'pg_foreign_priority', 'pg_gov_interest', 'pg_gov_interest_contracts', 'pg_gov_interest_org',
#                           'pg_granted_pgpubs_crosswalk', 'pg_inventor_disambiguated', 'pg_inventor_not_disambiguated',
#                           'pg_ipc_at_issue', 'pg_location_disambiguated', 'pg_location_not_disambiguated',
#                           'pg_pct_data', 'pg_persistent_assignee', 'pg_persistent_inventor', 'pg_rel_app_text',
#                           'pg_us_rel_doc', 'pg_uspc_at_issue', 'pg_wipo_technology']}}
